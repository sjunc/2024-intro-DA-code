# %% [markdown]
# lecture 15
#
# pie()
# autopct explode startangle 시험
# explode = (0, 0.1 0, 0) 떨어뜨려서 그림.
# autopct = .f 1 안써주는 게 낫다.
#
# base color는 기억해둘것
# black이 k  blue가 b
#
#
# ax.pie
#
#  인구 데이터 읽기.
#
#  산점도
#
#  c=range(4) 첫번째 좌표부터 색상을 넣음.
#  plt.colorbar() 옆에 색상바를 생성. 위에 써인 range(4) 0, 1, 2, 3 의 숫자가 나옴. 색상은 x 값 순서임.
#
# 스타일 변경
#  style.use('default') 원래대로 돌아옴
#
# s, c 모두 사이즈로 지정하는 문제 시험
#
# np.random.normal 정규분표

# %%
import matplotlib.pyplot as plt

plt.scatter([1,2,3,4],[10,30,20,40], s = [30, 60, 90, 120], c = range(4))
plt.colorbar()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter([1,2,3,4],[10,30,20,40], s = [30, 60, 90, 120], c = range(4))
plt.colorbar()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter([1,2,3,4,5],[10,30,20,40,50], s = [30, 60, 90, 120,150], c = range(5), cmap='jet')
plt.colorbar()
plt.grid(True)
plt.show()
