# %% [markdown]
# <a href="https://colab.research.google.com/github/sjunc/2024-intro-DA-code/blob/main/w01_intro_DA_for_jupyter_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #01주 코딩 연습
# ## 코랩을 위한 주피터 노트북 기초

# %% [markdown]
# ## 간단한 데이터 시각화 기초

# %%
import numpy as np
np.__version__
# Out:
# '1.26.4'

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 22.0 MB/s eta 0:00:00
# ...

# %%
import koreanize_matplotlib

# %%
import matplotlib.pyplot as plt

plt.title('데이터 시각화를 위한 한글 준비와 기본 직선 그래프')
plt.plot([20, 3, 4, 33, 15])
plt.show()

# %%
plt.title('데이터 시각화를 위한 한글 준비와 기본 직선 그래프 2')
plt.plot([0, 1, 2, 3, 4], [20, 3, 4, 33, 15])
plt.show()

# %% [markdown]
# ### end of code
